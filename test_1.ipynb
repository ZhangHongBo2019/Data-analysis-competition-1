# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
fig,ax = plt.subplots(figsize=(12,9))
plt.scatter(x=np.random.randint(1,100,60),y=np.random.randint(1,100,60))
plt.show()
